# %% [markdown]
# # Importing input data

# %%
# !pip install num2words
import json
import re
import num2words
import decimal
from decimal import Decimal
# !pip install word2number
import word2number
from word2number import w2n
# Out:
# Collecting num2words
#   Using cached num2words-0.5.10-py3-none-any.whl (101 kB)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from num2words) (0.6.2)
# Installing collected packages: num2words
# Successfully installed num2words-0.5.10
# Collecting word2number
#   Downloading word2number-1.1.zip (9.7 kB)
# Building wheels for collected packages: word2number
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5580 sha256=824e25c96ed3c7f760aeb245a2effa4ddc8c93e28422eb496828af3d58ad85d1
#   Stored in directory: /root/.cache/pip/wheels/4b/c3/77/a5f48aeb0d3efb7cd5ad61cbd3da30bbf9ffc9662b07c9f879
# Successfully built word2number
# Installing collected packages: word2number
# Successfully installed word2number-1.1

# %%
with open('/content/input.json','r') as input_file:
  input_data = json.load(input_file)
  input_file.close()
  input_data1=json.dumps(input_data , indent=6)
  input_data_self=json.dumps(input_data)
  #print(input_data1)
 

    
 #CONVERTING FROM ROMAN TO INT 
  def romanToInt(s):
      """
     
      :type s: str
      :rtype: int
      """
      
      roman = {'I':1,'II':2,'III':3,'VI':6,'VII':7,'VIII':8,'V':5,'X':10,'L':50,'C':100,'D':500,'M':1000,'IV':4,'IX':9,'XL':40,'XC':90,'CD':400,'CM':900}
      
      i = 0
      num = ""
      
      for i in roman:
        if(s==i):
          
          s=roman[i]
          
          
          return (num2words.num2words(s))
  #CONVERTING FRACTION TO WORDS  
  def fraction(s):
    fraction=s.split("/")
    if(fraction[1]=='4'):
      return(num2words.num2words(int(fraction[0])) + " "+ "quarters")
    if(fraction[1]=='2' and fraction[0]=='1'):
      return("and a half")  
    return(num2words.num2words(int(fraction[0])) + " "+ num2words.num2words(int(fraction[1]) , to='ordinal')+"s")

  #CONVERTING UNITS TO WORDS
  def measuring_unit(s):
      """
      :type s: str
      :rtype: int
      """
      print(s)
      m_unit={'cr':'crore','nm':'nanometers','dm':'decimeters','dam':'dekameters','hm':'hectameteres','mi':'miles','m':'meters','cm':'centimeters','km':'kilometers','mm':'millimeters','ha':'hectares','m2':'square meters','cm2':'square centimeters','km2':'square kilometers','kmtwo':'square kilometers','mm2':'square millimeters','ha2':'square hectares','/km':'per kilometers','/cm':'per centimeteres','/km2':'per square kilometers','/ha':'per hectares','/mi':'per miles','km\u00b2':' square kilometers','/km\\u00b2':'per square kilometers','7/km\\u00b2':'seven per square kilometers'}
      
      for i in m_unit:
        if(s==i):
          s=m_unit[i]
          
           
      return (" "+ s)   
  #CONVERTING CURRENCY TO WORDS BOTH UNICODE AND NORMAL
  def currency(s):
    i=0
    s=s.replace("\\u00a3","£")
    s=s.replace("\\u20ac","€")
   
    if(s[i]=='€'):
      #print(s.replace("€","").replace(",","") + " euros")
      return(s.replace("€","") + " euros")
    elif(s[i]=='$'):
      #print(s.replace("$","").replace(",","") + " dollars")
      return(s.replace("$","") + " dollars")
    else:
      #print(s.replace("£","").replace(",","") + " pounds") 
      return(s.replace("£","") + " pounds") 
   

 


  #CONVERTING MULTI PATTERN NUMBERS
  def multipart(s):
    print(s)
    m=[x for x in s]
    
    t=""
    for i in m:
      if(i=='0'):
         i='o'
      elif(i=='-' or i==" "):
         i='sil'

      else:
        i=num2words.num2words(int(i))
      t=t+" "+i
    return(t)

#CONVERTING YEARS TO WORDS
  def year(s):
    splitat=2
    l,r=s[:splitat],s[splitat:]
    
    if(int(l)==20):
       
       return(num2words.num2words(s).replace("thousand and","thousand").replace("hundred and"," ").replace("-",""))
    
    
    if(int(l)<20 and int(r)<=9):
       
       return(num2words.num2words(l)+" "+ "o" +" "+num2words.num2words(r))
    if(int(l)<20 and int(r)>9):
       return(num2words.num2words(l) + " "+num2words.num2words(r).replace("-"," "))
    
 #CONVERTING DATE TO WORDS   
  def date(s):
    m=s.split(" ") 
    #print(m)
    if(len(m)==3):
      return("the" +" " + num2words.num2words(m[0],to='ordinal')+"  "+ "of" +"  "+ m[1]+ "  " +year(m[2]))
    else:
      return("the" +" " + num2words.num2words(m[0],to='ordinal')+"  "+ "of" +"  "+ m[1])
  def months(s):

    m_unit={'01': 'January','02':'February','03':'March','04':'April','05':'May','06':'June','07':'July','08':'August','09':'September','10':'October','11':'November','12':'December'}
    for i in m_unit:
      if(s==i):
       s=m_unit[i]
    return(s)    

 #CONVERTING SECOND DATE FORMAT TO WORDS
  def date2(s):
   
    m=s.split("-")
    print(m)
    print("the" + " "+ num2words.num2words(int(m[2]), to = 'ordinal')+" "+ "of" +   " "+ months(m[1]) + " " + num2words.num2words(m[0]))
    return("the" + " "+ num2words.num2words(int(m[2]), to = 'ordinal')+" "+ "of" +   " "+ months(m[1]) + " " + num2words.num2words(m[0]))
  
  #CONVERTING DECIMAL TO WORDS
  def decimal(s):
   m=s.split(".")
   t=" "
   for x in m[1]:
     t+=num2words.num2words(int(x)) + " "
   #print(t)
   #print(num2words.num2words(int(m[0]))+" "+ "point" +" "+num2words.num2words(int(m[1])))
   return(num2words.num2words(int(m[0])).replace("-"," ")+" "+ "point" +" "+ t)
 
 #CONVERT BYTES TO WORDS
  def convert(s):
     
    
     
     m_byte={'MB':"megabytes",'PB':"petabytes",'GB':"gigabytes",'KB':"kilobytes",' KB':"kilobytes",'AM': 'a m','PM':'p m',' MB':"megabytes",' PB':"petabytes"}
     for i in m_byte:
       if(s==i):
         r=m_byte[i]
     
     return(" "+ r)
 #AVOIDING CACHING OF REGULAR EXPRESSIONS 
  re.purge()
 
 #CONVERTING SID AND INPUT_TOKENS  
  def reconvert(s):
     
     m= s.split(": ")
     #print(":"+" "+str(w2n.word_to_num(m[1])))
     return(":"+" "+ str(w2n.word_to_num(m[1])))

 #CONVERTING TO SELF
  def self(s):
    #print(s)
    if(s=="sid"):
      return("sid")
    if(s=="output_tokens"):
      return("output_tokens")
    if(s=="input_tokens"):
      return("input_tokens")
    if(len(s)==2):
      if(s=='mi'or s=='mm' or s=='km' or s=='cm'or s=='th' or s=='\\u'):
        return(s)
    
    if(s=='January'or s=='February' or s=='March' or s=='April' or s=='May' or s=='June' or s=='July' or s=='August' or s=='September' or s=='October' or s=='November' or s=='December' ):    
      return(s.lower())
    if(s=='million' or s=='Million' or s=='cr' or s=='Rs' or s=='percent'):
      return(s)
   
  
    else:
      return("<self>")
   
  #CONVERT TIME TO WORDS 
  def time(s):
    m=s.split(":")
    if(len(m)==3):
      return(m[0]+" "+"hours"+" "+m[1]+" "+ "minutes"+" "+m[2]+" "+"seconds")
    print(m)
    if(m[1]=='zero'):
      return(m[0])
    else:  
      return(m[0]+ " " + m[1])  

  def complicated_conversion(s):
    m=s.split(" ")
    print(m[0]+" "+num2words.num2words(int(m[1].replace(","," ")), to='ordinal'))
    return(m[0]+" "+num2words.num2words(int(m[1].replace(","," ")), to='ordinal').replace("-"," "))


    
  input_data1 = re.sub(r"\b[a-zA-z][a-z]+[/s_\b]*[a-zA-Z]*", lambda x: self(x.group(0)), input_data1)
  input_data1 = re.sub(r"\b(?=\b[MCDXLVI]{1,6}\b)M{0,4}(?:CM|CD|D?C{0,3})(?:XC|XL|L?X{0,3})(?:IX|IV|V?I{0,3})\b", lambda x: romanToInt(x.group(0)) , input_data1)
  #print(input_data1)

 
  
  input_data1 = re.sub(r"\s*[A-Z]B\b",lambda x: convert(x.group(0)), input_data1)
  
  #input_data1 = re.sub(r"-3/5", lambda x: x.group(0).replace("-","minus "), input_data1)

  input_data1 = re.sub(r"(\b[A-Z][A-Z]*\b)",lambda x: x.group(0).lower().replace("", " ")[1: -1], input_data1)
  input_data1 = re.sub(r"(\b[A-Z]{3}[a-z]+\b)",lambda x: x.group(0).lower().replace("", " ")[1: -1], input_data1)
  input_data1 = re.sub(r"(\b[A-Z].\b)",lambda x: x.group(0).lower().replace(".", " ")[1: -1], input_data1)
  input_data1 = re.sub(r"([A-Z].\s[A-Z].)",lambda x: x.group(0).lower().replace(".", " ")[1: -1], input_data1)
  input_data1 = re.sub(r"(\b[A-Z]{2}\b)",lambda x: x.group(0).lower().replace("", " ")[1: -1], input_data1)
  input_data1 = re.sub(r"august","<self>", input_data1)
  #print(input_data1)

 
  #print(input_data1)
 #RULES 
  re.purge()
  input_data1 = re.sub(r"[A-Z]+.\sI.",lambda x: x.group(0).lower().replace("."," ") , input_data1)
  input_data1 = re.sub(r"[0-9]+[/][0-9]+",lambda x: fraction(x.group(0)), input_data1)
  
  input_data1 = re.sub(r"[0-9]+([-][0-9]+){3,4}",lambda x: multipart(x.group(0)) , input_data1)
  input_data1 = re.sub(r"[0-9]+(\s[0-9]+){2,4}",lambda x: multipart(x.group(0)) , input_data1)
  input_data1 = re.sub(r"[0-9]+([-][0-9]+){2,4}\s[0-9]",lambda x: multipart(x.group(0)) , input_data1)
  input_data1 = re.sub(r"\\u2014",'sil', input_data1)
  

  input_data1 = re.sub(r"[0-9]+\s[A-za-z]+\s[0-9]{4}",lambda x: date(x.group(0)), input_data1)
  input_data1 = re.sub(r"[0-9]+\s[A-za-z]{3,8}\b",lambda x: date(x.group(0)), input_data1)
  input_data1 = re.sub(r"[0-9]{4}([-][0-9]+){2}",lambda x: date2(x.group(0)), input_data1)

  input_data1 = re.sub(r"([0-9]+m\b)", lambda x: x.group(0).replace("m"," million"), input_data1)
  input_data1 = re.sub(r"([0-9]+M\b)", lambda x: x.group(0).replace("M"," million"), input_data1)
  input_data1 = re.sub(r"(M.\b)", lambda x: x.group(0).replace("M."," m"), input_data1)
  input_data1 = re.sub(r"(b-\b)", lambda x: x.group(0).replace("b-"," b"), input_data1)
  input_data1 = re.sub(r"\\u00a3[0-9]+,[0-9]*",lambda x: currency(x.group(0)), input_data1)
  input_data1 = re.sub(r"\\u00a3[0-9]+\s[a-z]+",lambda x: currency(x.group(0)), input_data1)
  input_data1 = re.sub(r"\\u00a3[0-9]+.[0-9]+\s[a-z]+",lambda x: currency(x.group(0)), input_data1)
  input_data1 = re.sub(r"\\u20ac[0-9]+,[0-9]*",lambda x: currency(x.group(0)), input_data1)
  input_data1 = re.sub(r"\\u20ac[0-9]+\s[a-z]+",lambda x: currency(x.group(0)), input_data1)
  input_data1 = re.sub(r"\\u20ac[0-9]+.[0-9]+\s[a-z]+",lambda x: currency(x.group(0)), input_data1)
  input_data1 = re.sub(r"\b[12][0-9]{3}\b",lambda x: year(x.group(0)), input_data1)
  input_data1 = re.sub(r"[$£€][0-9]{1}[,][0-9]{3}[,][0-9]{3}\b",lambda x: currency(x.group(0).replace(",","")), input_data1)
  input_data1 = re.sub(r"[$£€][0-9]+,[0-9]+",lambda x: currency(x.group(0)), input_data1)
  input_data1 = re.sub(r"[$£€][0-9]+\s[a-z]+",lambda x: currency(x.group(0)), input_data1)
  input_data1 = re.sub(r"[$£€][0-9]+(million)",lambda x: currency(x.group(0)), input_data1)
  input_data1 = re.sub(r"[$£€][0-9]+.[0-9]+\s[a-z]+",lambda x: currency(x.group(0)), input_data1)
  
  
  input_data1 = re.sub(r"([0-9]+[.][0-9]+)", lambda x:decimal(x.group(0)), input_data1)
  input_data1 = re.sub(r"[0-9]*/[a-z0-9]+\\u00b2", lambda x: measuring_unit(x.group(0)), input_data1)
  input_data1 = re.sub(r"[-+]?[0-9]*\.?[0-9]*[a-z0-9]+\\u00b2", lambda x: measuring_unit(x.group(0)), input_data1)
  
  input_data1 = re.sub(r"[a-z]+\\u00b2", lambda x: measuring_unit(x.group(0)), input_data1)

  input_data1 = re.sub(r"/[a-z0-9]+", lambda x: measuring_unit(x.group(0)), input_data1)

  input_data1 = re.sub(r"[-+]?[0-9]*\.?[0-9]*/[a-z0-9]+(two)*", lambda x: measuring_unit(x.group(0)), input_data1)
  #print("HELLO")
  input_data1 = re.sub(r"[a-z]+-[a-z]+", lambda x: x.group(0).replace("-"," "), input_data1)
  input_data1 = re.sub(r"\s[a-zA-Z]{2}\b", lambda x: measuring_unit(x.group(0).strip()), input_data1)
  
  #print(input_data1)
  input_data1 = re.sub(r"Rs","Rupees", input_data1)
  input_data1 = re.sub(r"\brs\b","rupees", input_data1)
  input_data1 = re.sub(r"\sha\b","hectares", input_data1)
  input_data1 = re.sub(r"\'\s"," ", input_data1)
  
  input_data1 = re.sub(r"([0-9]+,[0-9]+)", lambda x: num2words.num2words(int(x.group(0).replace(",",""))).replace("-"," ").replace("thousand and","thousand").replace("hundred and","hundred"), input_data1)
  input_data1 = re.sub(r"[a-z]+\s(\d+),", lambda x: complicated_conversion(x.group(0)), input_data1)
  
  input_data1 = re.sub(r"(\d+)", lambda x: num2words.num2words(int(x.group(0))).replace("-"," "), input_data1)
  
  
  #print(input_data1)
  input_data1 = re.sub(r"[a-z]+:\s*[a-z]+\s*[a-z]+", lambda x: time(x.group(0)), input_data1)
  input_data1 = re.sub(r"[a-z]+:\s*[a-z]+:\s*[a-z]+", lambda x: time(x.group(0)), input_data1)
  #print(input_data1)
  input_data1 = re.sub(r"-twenty two", lambda x: x.group(0).replace("-","minus "), input_data1)
  input_data1 = re.sub(r"pm",lambda x: x.group(0).replace("pm"," p m "), input_data1)
  input_data1 = re.sub(r"p.m.",lambda x: x.group(0).replace("p.m."," p m "), input_data1)
  input_data1 = re.sub(r"a.m.",lambda x: x.group(0).replace("a.m."," a m "), input_data1)
  input_data1 = re.sub(r"am",lambda x: x.group(0).replace("am"," a m "), input_data1)
  input_data1 = re.sub(r"pst",lambda x: x.group(0).replace("pst"," p s t "), input_data1)
  input_data1 = re.sub(r"PM",lambda x: x.group(0).replace("PM"," p m "), input_data1)
  input_data1 = re.sub(r"input_tokens",lambda x: x.group(0).replace("input_tokens","output_tokens"), input_data1)
 # input_data1 = re.sub(r"([\b.\b])", " sil ", input_data1)
  input_data1 = re.sub(r":(\s[a-z]+)+-*[a-z]*", lambda x: reconvert(x.group(0)), input_data1)
  input_data1 = re.sub(r"[0-9]+(st)", lambda x: num2words.num2words(int(x.group(0).replace("st","")), to='ordinal'), input_data1)
  input_data1 = re.sub(r"[0-9]+(nd)", lambda x: num2words.num2words(int(x.group(0).replace("nd","")), to='ordinal'), input_data1)
  input_data1 = re.sub(r"[0-9]+(th)", lambda x: num2words.num2words(int(x.group(0).replace("th","")), to='ordinal'), input_data1)

  input_data1 = re.sub(r"[?!.;'()\\//]",  'sil' , input_data1)
 
  input_data1 = re.sub(r"%", " percent ", input_data1)
  input_data1 = re.sub(r"pc", " percent ", input_data1)
 
  input_data1 = re.sub(r"\s\",\",", "\" sil\" , " , input_data1)
  input_data1 = re.sub(r"\s\":\","," \"sil \"," , input_data1)
  input_data1 = re.sub(r" \\", "sil" , input_data1)
  #input_data1 = re.sub(r" \" ", "sil" , input_data1)
  #input_data1 = re.sub(r" ["]["] " , " ["]  ", input_data1)
  input_data1 = re.sub(r"\ba\b","<self>" , input_data1)
  input_data1 = re.sub(r"<self>'<self>","<self>" , input_data1)
  input_data1 = re.sub(r"<self>sils","<self>" , input_data1)
  
  print(input_data1)

  with open("solution_file.json", "w") as outfile:
    outfile.write(input_data1)
# Out:
# 1-881089-97-5
# 978-0-304-35252-4
# 0-8387-1972-4
# 1-84176-376-4
# 978-1-84176-376-7
# 0-671-22542-1
# 0-8032-8749-6
# 978-0-230-22808-5
# 1-873616-02-3
# 1-57392-979-4
# 81-85070-79-2
# 978-81-85070-79-7
# 84-933702-1-5
# 978-3-933375-00-1
# 3-7885-0023-9
# 0-7946-0435-8
# 978-0-7946-0435-6
# 5-7867-0060-7
# 5-224-01318-6
# 1-898051-22-4
# 978-1-898051-22-0
# 0 7506 0625 8
# 0 521 400775
# 3 9806773 4 6
# 2009-09-10 0
# ['2008', '01', '08']
# the eighth of January two thousand and eight
# 7/km\u00b2
# /km\u00b2
# /km2
# /km2
# /s
# /s
# of
# of
# of
# of
# of
# of
# of
# of
# mi
# km
# of
# of
# of
# km
# mi
# of
# mm
# of
# cr
# cm
# cm
# of
# km
# of
# of
# of
# of
# of
# of
# km
# mi
# of
# october twenty-first
# january fourteenth
# october first
# may twenty-eighth
# may twenty-ninth
# november twentieth
# ['one', 'thirty four']
# ['two', 'fifty p']
# ['five', 'ten']
# ['three', 'twenty one']
# ['nine', 'zero a']
# ['five', 'zero p']
# ['ten', 'twenty three']
# ['three', ' forty three']
# ['five', 'thirty a']
# ['five', 'fifty three']
# ['four', 'fifty six']
# ['four', 'sixteen']
# ['seven', 'zero p']
# ['eleven', 'zero p']
# ['fourteen', 'forty five']
# ['eleven', 'fifty five']
# ['nineteen', 'zero']
# ['nine', 'thirty']
# ['eleven', 'zeroam']
# ['nine', 'thirty']
# ['one', 'fifty four']
# ['twenty', ' forty three']
# ['eleven', 'thirty']
# ['eighteen', 'fifteen']
# ['two', 'ten']
# ['three', 'thirty five']
# ['two', 'twenty seven']
# ['twelve', 'thirty']
# [
#       {
#             "sid": 0,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "one hundred",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "ninety point  zero ",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 1,
#             "output_tokens": [
#                   "i s b n",
#                   " one sil eight eight one o eight nine sil nine seven sil five",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "sil",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "sil",
#                   "nineteen eighty one",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 2,
#             "output_tokens": [
#                   "<self>",
#                   "the fourteenth  of  june  two thousand fourteen",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "silutwentyacthe fourth  of  million",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "silutwentyacfivesilthe seventh  of  million",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 3,
#             "output_tokens": [
#                   "<self>",
#                   "the twenty first  of  may  two thousand thirteen",
#                   "<self>",
#                   "<self>",
#                   "seventeen ninety sixths",
#                  " sil" ,
#                   "the eighth  of  march  nineteen ninety six",
#                   "sil",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 4,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 5,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>sil<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 6,
#             "output_tokens": [
#                   "<self>",
#                   "the twentieth  of  january  two thousand ten",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 7,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "eighteen",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   " seven per square kilometers",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 8,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "two thousand six",
#                   "-",
#                   "seven",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "$the tenth  of  million",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 9,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "ninety nine point  zero five  percent ",
#                   "<self>",
#                  " sil" ,
#                   "zero point  three two  percent ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "zero point  six three  percent ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 10,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "seven two hundred and eighty thirds",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two hundred and twenty seven",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 11,
#             "output_tokens": [
#                   "sil"",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil ",
#                   "<self>",
#                   "four",
#                   "sil ",
#                   "<self>",
#                   "<self>",
#                   "sil ",
#                   "eleven",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 12,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "eighteen seventy three",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 13,
#             "output_tokens": [
#                   "i s b n",
#                   " nine seven eight sil o sil three o four sil three five two five two sil four",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "two thousand ten",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 14,
#             "output_tokens": [
#                   "sil"",
#                   "<self>",
#                   "sil ",
#                   "<self>",
#                   "the first  of  and <self> half",
#                   "sil",
#                   "<self>",
#                   "sil",
#                   "<self>",
#                   "<self>",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 15,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "<self>",
#                   "eleven",
#                   "<self>",
#                   "<self>",
#                   "ten",
#                   "<self>",
#                   "sil",
#                   "one thousand, nine hundred eight miles",
#                   "sil",
#                   "three thousand seventy kilometers",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 16,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "four thirty eighths",
#                   "<self>",
#                   "<self>",
#                   "thirty four",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "forty eight",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "seven eighty sixths",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 17,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "<self>",
#                   "one thirty four",
#                   "<self>",
#                   "<self>",
#                   "one",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 18,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "thirty nine thousand, eight hundred forty four dollars",
#                   "<self>",
#                   "twenty one thousand, seven hundred sixty one dollars",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 19,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "the fifty seventh  of  percent",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 20,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "fourth",
#                   "<self>",
#                   "two thousand seven",
#                   "<self>",
#                   "<self>",
#                   "eightth",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 21,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "tenth",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 22,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "two thousand eleven",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 23,
#             "output_tokens": [
#                   "<self>",
#                   "two fifty  p m ",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 24,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil ",
#                   "fifty thousand pounds",
#                   "sil",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "<self>",
#                   "n <self> c",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "nineteen ninety nine",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 25,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 26,
#             "output_tokens": [
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "sil",
#                   "october twenty first two thousand fifteen",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 27,
#             "output_tokens": [
#                   "<self>",
#                   "thirty fourth",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sixty seventh",
#                   "<self>",
#                   "sixty eightth",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "thirty fourth",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 28,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "nine hundred and seventeen twentieths",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"",
#                   "<self>",
#                   "<self>",
#                   "sil"",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 29,
#             "output_tokens": [
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "sil ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "nineteen seventy seven",
#                   "i s b n",
#                   " o sil eight three eight seven sil one nine seven two sil four",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "two thousand five",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 30,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "one thousand, six hundred eighty five",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "five hundred and sixty eight point  two ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "two hundred and nineteen point  four  per square kilometers",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 31,
#             "output_tokens": [
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 32,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 33,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "five hundred million pounds",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 34,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two thousand six",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "seven hundred fifty thousand dollars",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 35,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "fifteen ninety nine",
#                   "<self>",
#                   "sixteen o one",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 36,
#             "output_tokens": [
#                   "<self>",
#                   "sil ",
#                   "three point  one four ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 37,
#             "output_tokens": [
#                   "january fourteenth two thousand eight",
#                   "five ten p m  p s t",
#                   "sil",
#                   "the eighth of January two thousand and eight",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 38,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "nineteenth",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 39,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "<self>",
#                   "sil",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "d n <self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 40,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two thousand ten",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "twelve thousand",
#                   "<self>",
#                   "<self>",
#                   "two thousand thirteen",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 41,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "one hundred and fifty eight",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "four hundred and sixty four point  seven ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "one hundred and seventy nine point  four  per square kilometers",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 42,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "ninety seven percent ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 43,
#             "output_tokens": [
#                   "i s b n",
#                   " one sil eight four one seven six sil three seven six sil four",
#                  " sil" ,
#                   "i s b n",
#                   " nine seven eight sil one sil eight four one seven six sil three seven six sil seven",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 44,
#             "output_tokens": [
#                   "sil"",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "seven million dollars",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "CHealth",
#                   "<self>",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 45,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "d b l",
#                   "<self>",
#                   "<self>",
#                   "nine",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 46,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"",
#                   "<self>",
#                   "sil"",
#                   "<self>",
#                   "sil"",
#                   "<self>",
#                   "sil"",
#                   "<self>",
#                   "two",
#                   "<self>",
#                   "twenty three twenty one",
#                   "minus twenty two",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "k j v",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 47,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "three hundred and sixty seven sixths",
#                   "b c",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 48,
#             "output_tokens": [
#                   "nineteen seventy three",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "fourteenth",
#                   "u s",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 49,
#             "output_tokens": [
#                   "<self>",
#                   "nineteen eighty four",
#                   "<self>",
#                   "sil",
#                   "eighty five",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "seven",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 50,
#             "output_tokens": [
#                   "i s b n",
#                   " o sil six seven one sil two two five four two sil one",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "ssil",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 51,
#             "output_tokens": [
#                   "sil"",
#                   "thirty five million dollars",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 52,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 53,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 54,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "eighteen",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sixteen",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 55,
#             "output_tokens": [
#                   "two hundred and twenty",
#                  " sil" ,
#                   "two hundred and twenty six",
#                   "sil",
#                   "i s b n",
#                   " o sil eight o three two sil eight seven four nine sil six",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 56,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "nine zero <self> m",
#                   "<self>",
#                   "five zero p m",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 57,
#             "output_tokens": [
#                   "sil"",
#                   "<self>",
#                   "t n <self>",
#                   "<self>",
#                   "<self>",
#                   "six twenty fourths",
#                   "sil ",
#                   "<self>",
#                   "sil"",
#                   "<self>",
#                   "<self>",
#                   "sil"",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "t v",
#                   "<self>",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 58,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "two thousand six",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "one hundred and nine",
#                  " sil" ,
#                   "<self>",
#                   "twenty three",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 59,
#             "output_tokens": [
#                   "sil"",
#                   "<self>",
#                   "ten twenty three",
#                   "<self>",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 60,
#             "output_tokens": [
#                   "b m c",
#                   "<self>",
#                   "<self>",
#                   "three  forty three",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 61,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two point  six two ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two point  nine five ",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 62,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "november nineteen eighty three",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "nine hundred thousand dollars",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 63,
#             "output_tokens": [
#                   "sil"",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "four twentieths",
#                   "sil",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 64,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two thousand seven",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 65,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "fifty",
#                   "<self>",
#                   "sil",
#                   "fifteen m",
#                   "sil",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 66,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "one hundred",
#                   "<self>",
#                   "<self>",
#                   "eighteen",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "one hundred and two point  one ",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 67,
#             "output_tokens": [
#                   "<self>",
#                   "fiveth",
#                   "<self>",
#                   "sil"",
#                   "<self>",
#                   "sil"",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "the tenth  of  october  nineteen forty one",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "february nineteen forty four",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 68,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "s b h s s",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 69,
#             "output_tokens": [
#                   "i s b n",
#                   " nine seven eight sil o sil two three o sil two two eight o eight sil five",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "sil",
#                   "two thousand one",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 70,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "forty nine thousand, four hundred fifteen dollars",
#                   "<self>",
#                   "thirty one thousand, seven hundred forty three dollars",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 71,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "nine p m",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "five thirty <self> m",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 72,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "sil ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "twenty kilometers",
#                   "sil",
#                   "twelve point  four three  miles",
#                   "sil",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 73,
#             "output_tokens": [
#                   "<self>",
#                   "five fifty three",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "three",
#                   "sixty four ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 74,
#             "output_tokens": [
#                   "three hundred and thirty nine three hundred and fortieths",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "<self>",
#                   "<self>"
#             ]
#       },
#       {
#             "sid": 75,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "five point  six five ",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "fourteen point  six  kmtwo",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 76,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "six eighths",
#                   "<self>",
#                   "twelve eighths",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 77,
#             "output_tokens": [
#                   "<self>",
#                  " sil" ,
#                   "nineteen twenty nine",
#                  " sil" ,
#                   "p",
#                   "sil",
#                   "forty seven",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 78,
#             "output_tokens": [
#                   "i s b n",
#                   " one sil eight seven three six one six sil o two sil three",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "the twenty second  of  september  two thousand eleven",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 79,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "seven hundred and seventy four",
#                   "<self> b c",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 80,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 81,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "one thousand fifty four",
#                   "<self>",
#                   "<self>",
#                   "two hundred and fifty three",
#                   "<self>",
#                   "<self>",
#                   "six",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 82,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two thousand eleven",
#                   "<self>",
#                   "<self>",
#                   "four thousand, seven hundred seventeen",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 83,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "nineteen eighty",
#                   "<self>",
#                   "nineteen ninety",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 84,
#             "output_tokens": [
#                   "sil"",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 85,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "twenty one ",
#                   "<self>",
#                   "twenty onest",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "eighteen seventy eight",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 86,
#             "output_tokens": [
#                   "sil"",
#                   "two thousand fourteen",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "six point  six ",
#                   "<self>",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 87,
#             "output_tokens": [
#                   "<self>",
#                   "october first two thousand eleven",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two thousand eleven",
#                   "<self>",
#                   "x",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                  " sil" ,
#                   "u k",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 88,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "fourth",
#                   "sil",
#                   "seventh",
#                   "sil",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 89,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
# ...
#             "output_tokens": [
#                   "<self>",
#                   "november twentieth two thousand thirteen",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 196,
#             "output_tokens": [
#                   "sil"",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "h c",
#                   "two",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 197,
#             "output_tokens": [
#                   "sil"",
#                   "two hundred and fifty million dollars",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 198,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "fifteen",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "the twelfth  of  july  two thousand six",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 199,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two thousand four",
#                   "<self>",
#                   "sil",
#                   "i n e",
#                   "sil",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "one hundred and eight",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 200,
#             "output_tokens": [
#                   "<self>",
#                  " sil" ,
#                   "nineteen seventy two",
#                  " sil" ,
#                   "i s b n",
#                   " three sil seven eight eight five sil o o two three sil nine",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 201,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two thousand thirteen",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two twenty seven:seven",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 202,
#             "output_tokens": [
#                   "sil"",
#                   "l <self>",
#                   "i n s u m i s i o n",
#                   "v o l u n t <self> r i <self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 203,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "thirteen",
#                   "<self>",
#                   "<self>",
#                   "nineteen ninety one",
#                   "<self>",
#                   "two thousand three",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two hundred and eighty six-two hundred and twenty-three",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 204,
#             "output_tokens": [
#                   "i s b n",
#                   " three sil nine eight o six seven seven three sil four sil six",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 205,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two thousand",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two thousand one",
#                   "<self>",
#                   "twenty",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 206,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "<self>",
#                   "nineteen sixty",
#                   "sil",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 207,
#             "output_tokens": [
#                   "<self>",
#                   "seven hundred and twenty five",
#                   "<self>",
#                   "<self>",
#                   "nineteen kilometers",
#                   "sil",
#                   "twelve miles",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 208,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil",
#                   "one hundred and eighty sixth",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 209,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "sil",
#                   "two thousand four",
#                   "sil",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 210,
#             "output_tokens": [
#                   "i s b n",
#                   " o sil seven nine four six sil o four three five sil eight",
#                  " sil" ,
#                   "i s b n",
#                   " nine seven eight sil o sil seven nine four six sil o four three five sil six",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 211,
#             "output_tokens": [
#                   "sil"",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "fourteen",
#                   "w",
#                   " two o o nine sil o nine sil one o sil othree",
#                   "z",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 212,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "five fifty fourths",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "five hundred and fifty two",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 213,
#             "output_tokens": [
#                   "<self>",
#                   "two thousand seven",
#                   "-",
#                   "two thousand eight",
#                   "<self>",
#                   "<self>",
#                   "twenty point  six ",
#                   "<self>",
#                  " sil" ,
#                   "two point  six ",
#                   "<self>",
#                   "<self>",
#                   "five point  zero ",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 214,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "ninety nine percent ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 215,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "fifty thousand",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 216,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sixty four megabytes",
#                   "<self>",
#                   "g d d r",
#                   "three",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 217,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "fiveth",
#                   "<self>",
#                   "p <self>",
#                   "sixty five",
#                   "sil",
#                   "p <self>",
#                   "two hundred and eighty eight",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "p <self>",
#                   "sixty five two hundred and eighty eighths",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 218,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil"",
#                  " sil" ,
#                   "i s b n",
#                   " five sil seven eight six seven sil o o six o sil seven",
#                  " sil" ,
#                   "i s b n",
#                   " five sil two two four sil o one three one eight sil six",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "sil ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "wsilonesil",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 219,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "nineteen ninety three",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "nineteen ninety four",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 220,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two point  four nine ",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "two point  nine seven ",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 221,
#             "output_tokens": [
#                   "sil"",
#                   "<self>",
#                   "<self>",
#                   "one hundredGb  sils",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>-",
#                   "four",
#                   "<self>",
#                   "sil"",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 222,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "the first  of  seven eighths",
#                   "<self>",
#                   "<self>",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 223,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "four million, five hundred thousand dollars",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 224,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                  " sil" ,
#                   "<self>",
#                  " sil" ,
#                   "nineteen ninety five",
#                  " sil" ,
#                   "i s b n",
#                   " one sil eight nine eight o five one sil two two sil four",
#                  " sil" ,
#                   "i s b n",
#                   " nine seven eight sil one sil eight nine eight o five one sil two two sil o",
#                   "sil"
#             ]
#       },
#       {
#             "sid": 225,
#             "output_tokens": [
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "<self>",
#                   "twelve thirty",
#                   "<self>",
#                   "september two thousand eight",
#                   "sil"
#             ]
#       }
# ]

# %%
def solution(output_tokens):
  return ['<self>']*len(output_tokens) #todo: write your own solution

# %%
def solution_dump(solution_file_path):
  solution_data = []
  #print(input_data1)
  for input_sentence in input_data1:
    print(input_sentence)
    solution_sid = int(input_sentence['sid'])
    print(solution_sid)
    solution_tokens = solution(input_sentence['output_tokens'])
    solution_data.append({'sid':solution_sid,
                          'output_tokens':solution_tokens})

# %%
with open('/content/output.json','r') as output_file:
  output_data = json.load(output_file)
  output_file.close()
  print(output_data)
